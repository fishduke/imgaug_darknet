# %%
import numpy as np
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox
from imgaug.augmentables.bbs import BoundingBoxesOnImage
import os
import glob
import cv2

labeling = 1

def make_aug(image, count):
    # Sometimes(0.5, ...) applies the given augmenter in 50% of all cases,
    # e.g. Sometimes(0.5, GaussianBlur(0.3)) would blur roughly every second image.
    sometimes = lambda aug: iaa.Sometimes(0.5, aug)

    # Define our sequence of augmentation steps that will be applied to every image
    # All augmenters with per_channel=0.5 will sample one value _per image_
    # in 50% of all cases. In all other cases they will sample new values
    # _per channel_.
    seq = iaa.Sequential(
        [
            # apply the following augmenters to most images
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
            iaa.Flipud(0.2), # vertically flip 20% of all images
            # crop images by -5% to 10% of their height/width
            sometimes(iaa.CropAndPad(
                percent=(-0.05, 0.1),
                pad_mode=ia.ALL,
                pad_cval=(0, 255)
            )),
            sometimes(iaa.Affine(
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
                translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, # translate by -20 to +20 percent (per axis)
                rotate=(-5, 5), # rotate by -45 to +45 degrees
                shear=(-16, 16), # shear by -16 to +16 degrees
                order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
                cval=(0, 255), # if mode is constant, use a cval between 0 and 255
                mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
            )),
            # execute 0 to 5 of the following (less important) augmenters per image
            # don't execute all of them, as that would often be way too strong
            iaa.SomeOf((0, 5),
                [
                    sometimes(iaa.Superpixels(p_replace=(0, 1.0), n_segments=(20, 200))), # convert images into their superpixel representation
                    iaa.OneOf([
                        iaa.GaussianBlur((0, 3.0)), # blur images with a sigma between 0 and 3.0
                        iaa.AverageBlur(k=(2, 2)), # blur image using local means with kernel sizes between 2 and 7
                        iaa.MedianBlur(k=(3, 3)), # blur image using local medians with kernel sizes between 2 and 7
                    ]),
                    iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images
                    iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)), # emboss images
                    # search either for all edges or for directed edges,
                    # blend the result with the original image using a blobby mask
                    iaa.SimplexNoiseAlpha(iaa.OneOf([
                        iaa.EdgeDetect(alpha=(0.5, 1.0)),
                        iaa.DirectedEdgeDetect(alpha=(0.5, 1.0), direction=(0.0, 1.0)),
                    ])),
                    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5), # add gaussian noise to images
                    iaa.OneOf([
                        iaa.Dropout((0.01, 0.1), per_channel=0.5), # randomly remove up to 10% of the pixels
                        iaa.CoarseDropout((0.03, 0.15), size_percent=(0.02, 0.05), per_channel=0.2),
                    ]),
                    iaa.Invert(0.05, per_channel=True), # invert color channels
                    iaa.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
                    iaa.AddToHueAndSaturation((-20, 20)), # change hue and saturation
                    # either change the brightness of the whole image (sometimes
                    # per channel) or change the brightness of subareas
                    iaa.OneOf([
                        iaa.Multiply((0.5, 1.5), per_channel=0.5),
                        iaa.FrequencyNoiseAlpha(
                            exponent=(-4, 0),
                            first=iaa.Multiply((0.5, 1.5), per_channel=True),
                            second=iaa.ContrastNormalization((0.5, 2.0))
                        )
                    ]),
                    iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5), # improve or worsen the contrast
                    iaa.Grayscale(alpha=(0.0, 1.0)),
                    sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)), # move pixels locally around (with random strengths)
                    sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))), # sometimes move parts of the image around
                    sometimes(iaa.PerspectiveTransform(scale=(0.01, 0.1)))
                ],
                random_order=True
            )
        ],
        random_order=True
    )

    img = cv2.imread(image)

    img_path = image
    txt_path = img_path[:img_path.find('.')] + '.txt'
    txt = open(txt_path, "r")
    lines = txt.readlines()

    boxes = []
    class_name = []

    for i in range(len(lines)):
        label = lines[i].split(' ')
        x = float(label[1]) * img.shape[1]
        y = float(label[2]) * img.shape[0]
        w = int(float(label[3]) * img.shape[1])
        h = int(float(label[4][:len(label[4])-1]) * img.shape[0])

        if(labeling):            
            #for labeling
            x1 = x-w/2
            y1 = y-h/2
            x2 = x+w/2
            y2 = y+h/2
        else:
            #for rectangle
            x1 = int(x-w/2)
            y1 = int(y-h/2)
            x2 = int(x+w/2)
            y2 = int(y+h/2)
            cv2.rectangle(img, (x1,y1), (x2,y2), (255,0,0), 1)

        class_name.append(label[0])
        boxes.append(BoundingBox(x1,y1,x2,y2))
    txt.close()
    
    bounding_boxes = ia.BoundingBoxesOnImage(boxes, img.shape)
    seq = seq.to_deterministic()
    img_np = np.array(img)
    images_aug = seq.augment_image(img_np)
    bbs_aug = seq.augment_bounding_boxes([bounding_boxes])[0]
    aug = images_aug.astype(np.uint8)
    new_path = image[:image.rfind('.')]+"_"+str(count)
    if(labeling):    
        new_txt = open(new_path+".txt", "w")
        
    for i in range(len(bbs_aug.bounding_boxes)):
            bb_box = bbs_aug.bounding_boxes[i]

            if(labeling): 
                x1 = bb_box[0][0] /img.shape[1]
                y1 = bb_box[0][1] /img.shape[0]
                x2 = bb_box[1][0] /img.shape[1]
                y2 = bb_box[1][1] /img.shape[0]
                w = int(float(label[3]) * img.shape[1])
                h = int(float(label[4][:len(label[4])-1]) * img.shape[0])

                wid = x2-x1
                hei = y2-y1
                x = x1+wid/2
                y = y1+hei/2
                
                new_line = class_name[i] + " " + str(x) + " " + str(y) + " " + str(wid) + " " + str(hei) + "\n"
                new_txt.write(new_line)
                
            else:
                x1 = int(bb_box[0][0])
                y1 = int(bb_box[0][1])
                x2 = int(bb_box[1][0])
                y2 = int(bb_box[1][1])
                cv2.rectangle(aug, (x1, y1), (x2, y2), (255,0,255), 1)
           

    if(labeling==0):
        add = cv2.hconcat([img,aug])
        cv2.imshow("add",add)
        cv2.waitKey(0)
        cv2.destroyAllWindows()        
    else:
        new_txt.close()
        cv2.imwrite(new_path+".jpg",aug)
    
    seq.clear()

def main():
    augmentation_count = 2 #how many will you augmentate

    folder_path = '/dataset/Dataset_backup/Completion_dataset/basics_detector/5class/2024_02_06/person'
    folders = os.listdir(folder_path)

    # for folder in folders:
    #     path = os.path.join(folder_path, folder)
    path = folder_path

    images = glob.glob(f'{path}/*.jpg') + glob.glob(f'{path}/*.png')
    print("images size : ", len(images))

    num = 0
    for image in images:
        num += 1
        for count in range(augmentation_count):
            make_aug(image, count)
                                    
        msg = "\rprocessed : %.0f%%" % (num/len(images)*100.0)
        print(msg,end='')



main()
# Out:
# images size :  19341
# /home/fishduke/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `SimplexNoiseAlpha()` is deprecated. Use `BlendAlphaSimplexNoise` instead. SimplexNoiseAlpha is deprecated. Use BlendAlphaSimplexNoise instead. The order of parameters is the same. Parameter 'first' was renamed to 'foreground'. Parameter 'second' was renamed to 'background'.
#   warn_deprecated(msg, stacklevel=3)
# /home/fishduke/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `ContrastNormalization()` is deprecated. Use `imgaug.contrast.LinearContrast` instead.
#   warn_deprecated(msg, stacklevel=3)
# /home/fishduke/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `FrequencyNoiseAlpha()` is deprecated. Use `BlendAlphaFrequencyNoise` instead. FrequencyNoiseAlpha is deprecated. Use BlendAlphaFrequencyNoise instead. The order of parameters is the same. Parameter 'first' was renamed to 'foreground'. Parameter 'second' was renamed to 'background'.
#   warn_deprecated(msg, stacklevel=3)
# processed : 0%
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 196
#     191         msg = "\rprocessed : %.0f%%" % (num/len(images)*100.0)
#     192         print(msg,end='')
# --> 196 main()
#
# Cell In[1], line 189, in main()
#     187 num += 1
#     188 for count in range(augmentation_count):
# --> 189     make_aug(image, count)
#     191 msg = "\rprocessed : %.0f%%" % (num/len(images)*100.0)
#     192 print(msg,end='')
#
# Cell In[1], line 128, in make_aug(image, count)
#     126 img_np = np.array(img)
#     127 images_aug = seq.augment_image(img_np)
# --> 128 bbs_aug = seq.augment_bounding_boxes([bounding_boxes])[0]
#     129 aug = images_aug.astype(np.uint8)
#     130 new_path = image[:image.rfind('.')]+"_"+str(count)
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:1180, in Augmenter.augment_bounding_boxes(self, bounding_boxes_on_images, parents, hooks)
#    1118 def augment_bounding_boxes(self, bounding_boxes_on_images, parents=None,
#    1119                            hooks=None):
#    1120     """Augment a batch of bounding boxes.
#    1121
#    1122     This is the corresponding function to
#    (...)
#    1178
#    1179     """
# -> 1180     return self.augment_batch_(
#    1181         UnnormalizedBatch(bounding_boxes=bounding_boxes_on_images),
#    1182         parents=parents,
#    1183         hooks=hooks
#    1184     ).bounding_boxes_aug
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:3124, in Sequential._augment_batch_(self, batch, random_state, parents, hooks)
#    3121         order = sm.xrange(len(self))
#    3123     for index in order:
# -> 3124         batch = self[index].augment_batch_(
#    3125             batch,
#    3126             parents=parents + [self],
#    3127             hooks=hooks
#    3128         )
#    3129 return batch
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:3403, in SomeOf._augment_batch_(self, batch, random_state, parents, hooks)
#    3401     if len(active) > 0:
#    3402         batch_sub = batch.subselect_rows_by_indices(active)
# -> 3403         batch_sub = self[augmenter_index].augment_batch_(
#    3404             batch_sub,
#    3405             parents=parents + [self],
#    3406             hooks=hooks
#    3407         )
#    3408         batch = batch.invert_subselect_rows_by_indices_(active,
#    3409                                                         batch_sub)
#    3411 return batch
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:3633, in Sometimes._augment_batch_(self, batch, random_state, parents, hooks)
#    3631     if augmenters is not None and len(augmenters) > 0:
#    3632         batch_sub = batch.subselect_rows_by_indices(indices)
# -> 3633         batch_sub = augmenters.augment_batch_(
#    3634             batch_sub,
#    3635             parents=parents + [self],
#    3636             hooks=hooks
#    3637         )
#    3638         batch = batch.invert_subselect_rows_by_indices_(indices,
#    3639                                                         batch_sub)
#    3641 return batch
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:3124, in Sequential._augment_batch_(self, batch, random_state, parents, hooks)
#    3121         order = sm.xrange(len(self))
#    3123     for index in order:
# -> 3124         batch = self[index].augment_batch_(
#    3125             batch,
#    3126             parents=parents + [self],
#    3127             hooks=hooks
#    3128         )
#    3129 return batch
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/geometric.py:3078, in PiecewiseAffine._augment_batch_(self, batch, random_state, parents, hooks)
#    3074     if augm_value is not None:
#    3075         func = functools.partial(
#    3076             self._augment_keypoints_by_samples,
#    3077             samples=samples)
# -> 3078         cbaois = self._apply_to_cbaois_as_keypoints(augm_value, func)
#    3079         setattr(batch, augm_name, cbaois)
#    3081 return batch
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/meta.py:1686, in Augmenter._apply_to_cbaois_as_keypoints(cls, cbaois, func)
#    1682 from ..augmentables.utils import (convert_cbaois_to_kpsois,
#    1683                                   invert_convert_cbaois_to_kpsois_)
#    1685 kpsois = convert_cbaois_to_kpsois(cbaois)
# -> 1686 kpsois_aug = func(kpsois)
#    1687 return invert_convert_cbaois_to_kpsois_(cbaois, kpsois_aug)
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/imgaug/augmenters/geometric.py:3213, in PiecewiseAffine._augment_keypoints_by_samples(self, kpsois, samples)
#    3202 # TODO this could be done a little bit more efficient by
#    3203 #      removing first all KPs that are outside of the image
#    3204 #      plane so that no corresponding distance map has to
#    (...)
#    3210 # Much slower than directly augmenting the coordinates, but
#    3211 # here the only method that reliably works.
#    3212 dist_maps = kpsoi.to_distance_maps(inverted=True)
# -> 3213 dist_maps_warped = tf.warp(
#    3214     dist_maps,
#    3215     transformer,
#    3216     order=1,
#    3217     preserve_range=True,
#    3218     output_shape=(kpsoi.shape[0], kpsoi.shape[1],
#    3219                   len(kpsoi.keypoints))
#    3220 )
#    3222 kps_aug = ia.KeypointsOnImage.from_distance_maps(
#    3223     dist_maps_warped,
#    3224     inverted=True,
#    (...)
#    3228         None if len(kpsoi.shape) < 3 else kpsoi.shape[2])
#    3229 )
#    3231 for kp, kp_aug in zip(kpsoi.keypoints, kps_aug.keypoints):
#    3232     # Keypoints that were outside of the image plane before the
#    3233     # augmentation were replaced with (-1, -1) by default (as
#    3234     # they can't be drawn on the keypoint images).
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/skimage/transform/_warps.py:938, in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     931     if len(input_shape) == 3 and len(output_shape) == 2:
#     932         # Input image is 2D and has color channel, but output_shape is
#     933         # given for 2-D images. Automatically add the color channel
#     934         # dimensionality.
#     935         output_shape = (output_shape[0], output_shape[1],
#     936                         input_shape[2])
# --> 938     coords = warp_coords(coord_map, output_shape)
#     940 # Pre-filtering not necessary for order 0, 1 interpolation
#     941 prefilter = order > 1
#
# File ~/anaconda3/envs/imgaug/lib/python3.8/site-packages/skimage/transform/_warps.py:616, in warp_coords(coord_map, shape, dtype)
#     614 if len(shape) == 3:
#     615     coords_shape.append(shape[2])
# --> 616 coords = np.empty(coords_shape, dtype=dtype)
#     618 # Reshape grid coordinates into a (P, 2) array of (row, col) pairs
#     619 tf_coords = np.indices((cols, rows), dtype=dtype).reshape(2, -1).T
#
# MemoryError: Unable to allocate 68.3 GiB for an array with shape (3, 1500, 2666, 764) and data type float64
